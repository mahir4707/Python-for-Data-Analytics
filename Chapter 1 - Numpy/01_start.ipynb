# %%
print("Hello world")
# Out:
# Hello world

# %%
import numpy as np

arr = np.array([1,2,3])

# %%
arr[0:1]
# Out:
# array([1])

# %%
import csv

with open("output.csv", mode="r") as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Age', 'City']
# ['Mahir', '21', 'Ahmedabad']
# ['Aman', '22', 'Delhi']

# %%
import csv

data = [
    ["Name", "Age", "City"],
    ["Mahir", 21, "Ahmedabad"],
    ["Aman", 22, "Delhi"]
]

with open("output.csv", mode="w", newline="") as file:
    writer = csv.writer(file)
    writer.writerows(data)

# %%
from openpyxl import Workbook

wb = Workbook()
sheet = wb.active

sheet.append(["Name", "Marks"])
sheet.append(["Mahir", 85])
sheet.append(["Aman", 90])

wb.save("output.xlsx")

# %%
import json

data = {
    "name": "Mahir",
    "age": 21,
    "skills": ["Python", "SQL", "Data Analysis"]
}

with open("data.json", "w") as file:
    json.dump(data, file, indent=4)

# %%
import json

with open("data.json", "r") as file:
    data = json.load(file)

print(data["skills"])
# Out:
# ['Python', 'SQL', 'Data Analysis']

# %%
import os

print(os.getcwd())          # current directory
os.mkdir("new_folder")      # create folder
print(os.listdir())         # list files
# Out:
# c:\Python for Data Analytics\Chapter 1 - Numpy
# ['01_start.ipynb', 'data.json', 'new_folder', 'output.csv', 'output.xlsx']

# %%
from pathlib import Path

path = Path("data_folder")

path.mkdir(exist_ok=True)

file_path = path / "info.txt"

file_path.write_text("Pathlib is easy")
print(file_path.read_text())
# Out:
# Pathlib is easy

# %%
import logging

logging.basicConfig(
    filename="app.log",
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)

logging.info("Program started")
logging.warning("This is a warning")
logging.error("An error occurred")
